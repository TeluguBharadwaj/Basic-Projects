# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:\\Users\\telug\\OneDrive\\Desktop\\DS\\Data\\insurance1.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.shape
# Out:
# (1338, 7)

# %%
#finding missing values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#distribution of age
sns.set()
plt.figure(figsize=(6,6))
sns.distplot(df['age'])
plt.title('age distribution')
plt.show
# Out:
# C:\Users\telug\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(df.age)
# Out:
# (array([222., 140., 109., 128., 102., 137., 144., 114., 128., 114.]),
#  array([18. , 22.6, 27.2, 31.8, 36.4, 41. , 45.6, 50.2, 54.8, 59.4, 64. ]),
#  <BarContainer object of 10 artists>)

# %%
age=df['age']
props2= dict(boxes='red',whiskers='black',medians='blue',caps='green')
age.plot.box(color=props2,patch_artist=True,vert=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Observations:
# The Age of the insured approximately follow a uniform distribution with Mean of 39.2 and Median of 39.0, and with lowest age being 18 and highest being 64.
# There are no outlier values in the Age distribution in the data

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
#geder column
plt.figure(figsize=(6,6))
sns.countplot(x='sex',data=df)
plt.title('sex distribution')
plt.show()

# %%
#bmi distribution
sns.set()
plt.figure(figsize=(6,6))
sns.distplot(df['bmi'])
plt.title('bmi distribution')
plt.show
# Out:
# C:\Users\telug\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
bmi=df['bmi']
props2= dict(boxes='red',whiskers='black',medians='blue',caps='green')
bmi.plot.box(color=props2,patch_artist=True,vert=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# normal bmi range = 18.5 to 24.9

# %%
# Who is the insured with the highest BMI, and how does his charges compare to the rest?
df[df['bmi'] == df['bmi'].max()]
# Out:
#       age   sex    bmi  children smoker     region    charges
# 1317   18  male  53.13         0     no  southeast  1163.4627

# %%
df['charges'].mean(), df['charges'].median()
# Out:
# (13270.422265141257, 9382.033)

# %% [markdown]
# # observation
# The person with the highest BMI (least healthy, based on available data) is also one of the youngest (male, 18, non-smoker.)
# He is paying less premium than the mean, but significantly more than the median charges.

# %%
df['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
#children column
plt.figure(figsize=(6,6))
sns.countplot(x='children',data=df)
plt.title('children distribution')
plt.show()

# %%
df['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
#smoker column
plt.figure(figsize=(6,6))
sns.countplot(x='smoker',data=df)
plt.title('smoker distribution')
plt.show()

# %%
df['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
#region column
plt.figure(figsize=(6,6))
sns.countplot(x='region',data=df)
plt.title('region distribution')
plt.show()

# %%
#charges distribution
sns.set()
plt.figure(figsize=(6,6))
sns.distplot(df['charges'])
plt.title('charge distribution')
plt.show
# Out:
# C:\Users\telug\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
charges=df['charges']
props2= dict(boxes='red',whiskers='black',medians='blue',caps='green')
charges.plot.box(color=props2,patch_artist=True,vert=True)
# Out:
# <AxesSubplot:>

# %%
#corelation
heatmap=sns.heatmap(df.corr(),vmin=-1,vmax=1,annot=True)

# %% [markdown]
# # Observation:
# From the correlation heatmap, we can conclude that the premium charges show a weak positive correlation with Age and BMI of the insured, and a strong positive correlation with smoking habit.

# %%
sns.relplot(x='bmi',y='charges',hue='sex',data=df)

# %%
sns.relplot(x='bmi',y='charges',data=df)

# %%
#relationship between Charges, BMI and Smoking status
sns.relplot(x='bmi',y='charges',hue='smoker',data=df)

# %% [markdown]
# # observation
# the relationship between the bmi,smoking status and charges is intresting.
# The above two graphs shows that the insurance charges are high for smokers irrespective of thier bmi

# %%
#relationship between Charges, BMI and Smoking status
sns.relplot(x='age',y='charges',hue='smoker',data=df)

# %%
#observation
the insurance charges for non smokers is are relatively very low compared to those of smokers irrespective of thier age

# %%
sns.boxplot(x='charges',y='smoker')
# Out:
# <AxesSubplot:xlabel='charges', ylabel='smoker'>

# %% [markdown]
# # observation
# mean charges of a smoker is higher is than the mean charges of non-smoker

# %%
#proportion of smokers in different genders
plt.figure(figsize=(6,5))
chart = sns.countplot(y = 'sex', hue = 'smoker', data = df)
chart.set_yticklabels(['female', 'male'])
# Out:
# [Text(0, 0, 'female'), Text(0, 1, 'male')]
