# %%
#Loading the essential Libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# Ignore Warning 
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the dataset
pa=r"C:\Users\Admin\Desktop\Assesment\Demo Data - 20 Feb 2023.xlsx"

import pandas as pd

# Read the Excel file into a pandas dataframe
df = pd.read_excel(pa,sheet_name="Instrument - Spectrometer L", header=[0,1,2])

# Print the dataframe to verify that the data was read correctly
print(df.head())

left_cheek_baseline = df['Left Cheek']['Visit 1 - Baseline']

left_cheek = df['Left Cheek'][['Visit 1 - Baseline', 'Visit 2']]
# Out:
#   Unnamed: 0_level_0        Right Cheek                                      \
#   Unnamed: 0_level_1 Visit 1 - Baseline               Visit 1 - Timm
#   Unnamed: 0_level_2                  L      a      b              L      a
# 0                  1              49.74  10.59  19.58          50.83  11.56
# 1                  2              46.11  11.85  17.60          48.47  13.16
# 2                  3              52.65  13.84  17.48          53.06  12.41
# 3                  4              48.39  12.66  17.76          49.00  12.17
# 4                  5              51.16  12.85  18.79          51.42  11.93
#
#                                 ...         Left Cheek                        \
#          Visit 2                ... Visit 1 - Baseline Visit 1 - Timm
#        b       L      a      b  ...                  b              L      a
# 0  19.97   50.62  11.54  19.74  ...              18.33          51.45  11.64
# ...

# %% [markdown]
# ## Seperating columns

# %%
new_names = {'L': 'Left_Cheek_Visit 1 - Baseline L', 'a': 'Left_Cheek_Visit 1 - Baseline a', 'b': 'Left_Cheek_Visit 1 - Baseline b'}
left_cheek_baseline=left_cheek_baseline.rename(columns=new_names)

# %%
new_names
# Out:
# {'L': 'Left_Cheek_Visit 1 - Baseline L',
#  'a': 'Left_Cheek_Visit 1 - Baseline a',
#  'b': 'Left_Cheek_Visit 1 - Baseline b'}

# %%
#Seperating DataFrame for L A B for leftcheck visit 1 Baseline
left_cheek_visit1_baseline = df['Left Cheek']['Visit 1 - Baseline']

new_names = {'L': 'Left_Cheek_Visit 1 - Baseline L', 'a': 'Left_Cheek_Visit 1 - Baseline a', 'b': 'Left_Cheek_Visit 1 - Baseline b'}
left_cheek_visit1_baseline=left_cheek_visit1_baseline.rename(columns=new_names)

#Seperating DataFrame for L A B for leftcheck visit 1 Timm
left_cheek_visit1_Timm = df['Left Cheek']['Visit 1 - Timm']

new_names1 = {'L': 'Left_Cheek_Visit 1 - Timm L', 'a': 'Left_Cheek_Visit 1 - Timm a', 'b': 'Left_Cheek_Visit 1 - Timm b'}
left_cheek_visit1_Timm=left_cheek_visit1_Timm.rename(columns=new_names1)

#Seperating DataFrame for L A B for leftcheck visit 2
left_cheek_visit2 = df['Left Cheek']['Visit 2']

new_names1 = {'L': 'Left_Cheek_Visit 2 L', 'a': 'Left_Cheek_Visit 2 a', 'b': 'Left_Cheek_Visit 2 b'}
left_cheek_visit2=left_cheek_visit2.rename(columns=new_names1)


#Seperating DataFrame for L A B for leftcheck visit 3
-left_cheek_visit3 = df['Left Cheek']['Visit 3']

new_names1 = {'L': 'Left_Cheek_Visit 3 L', 'a': 'Left_Cheek_Visit 3 a', 'b': 'Left_Cheek_Visit 3 b'}
left_cheek_visit3=left_cheek_visit3.rename(columns=new_names1)
# Out:
#   Unnamed: 0_level_0        Right Cheek                                      \
#   Unnamed: 0_level_1 Visit 1 - Baseline               Visit 1 - Timm
#   Unnamed: 0_level_2                  L      a      b              L      a
# 0                  1              49.74  10.59  19.58          50.83  11.56
# 1                  2              46.11  11.85  17.60          48.47  13.16
# 2                  3              52.65  13.84  17.48          53.06  12.41
# 3                  4              48.39  12.66  17.76          49.00  12.17
# 4                  5              51.16  12.85  18.79          51.42  11.93
#
#                                 ...         Left Cheek                        \
#          Visit 2                ... Visit 1 - Baseline Visit 1 - Timm
#        b       L      a      b  ...                  b              L      a
# 0  19.97   50.62  11.54  19.74  ...              18.33          51.45  11.64
# ...

# %% [markdown]
# # SPRECTROMETER ANALYSIS

# %% [markdown]
# # Left_Cheek

# %% [markdown]
# # Improvement after (15-20min) of application of the product

# %%
plt.plot(left_cheek_visit1_baseline['Left_Cheek_Visit 1 - Baseline L'],color='red')
plt.plot(left_cheek_visit1_Timm['Left_Cheek_Visit 1 - Timm L'],color='blue')

# %% [markdown]
# # Improvement after 7 Days of appllication of the product

# %%
plt.plot(left_cheek_visit1_baseline['Left_Cheek_Visit 1 - Baseline L'],color='red')
plt.plot(left_cheek_visit2['Left_Cheek_Visit 2 L'],color='green')

# %% [markdown]
# # Improvement after 14 Days of application of the product

# %%
plt.plot(left_cheek_visit1_baseline['Left_Cheek_Visit 1 - Baseline L'],color='red')
plt.plot(left_cheek_visit3['Left_Cheek_Visit 3 L'],color='black')

# %% [markdown]
# # Right_cheek

# %%
# Seperating DataFrame for L A B for Right cheek visit 1 Baseline
Right_cheek_visit1_baseline = df['Right Cheek']['Visit 1 - Baseline']

new_names = {'L': 'Right_Cheek_Visit 1 - Baseline L', 'a': 'Right_Cheek_Visit 1 - Baseline a', 'b': 'Right_Cheek_Visit 1 - Baseline b'}
Right_cheek_visit1_baseline=Right_cheek_visit1_baseline.rename(columns=new_names)

#Seperating DataFrame for L A B for Rightcheck visit 1 Timm
Right_cheek_visit1_Timm = df['Right Cheek']['Visit 1 - Timm']

new_names2 = {'L': 'Right_Cheek_Visit 1 - Timm L', 'a': 'Right_Cheek_Visit 1 - Timm a', 'b': 'Right_Cheek_Visit 1 - Timm b'}
Right_cheek_visit1_Timm=Right_cheek_visit1_Timm.rename(columns=new_names2)

#Seperating DataFrame for L A B for Rightcheck visit 2
Right_cheek_visit2 = df['Right Cheek']['Visit 2']

new_names2 = {'L': 'Right_Cheek_Visit 2 L', 'a': 'Right_Cheek_Visit 2 a', 'b': 'Right_Cheek_Visit 2 b'}
Right_cheek_visit2=Right_cheek_visit2.rename(columns=new_names2)


#Seperating DataFrame for L A B for Rightcheck visit 3
Right_cheek_visit3 = df['Right Cheek']['Visit 3']

new_names2 = {'L': 'Right_Cheek_Visit 3 L', 'a': 'Right_Cheek_Visit 3 a', 'b': 'Right_Cheek_Visit 3 b'}
Right_cheek_visit3=Right_cheek_visit3.rename(columns=new_names2)

# %% [markdown]
# # Improvement after (15-20min) of application of the product

# %%
plt.plot(Right_cheek_visit1_baseline['Right_Cheek_Visit 1 - Baseline L'],color='red')
plt.plot(Right_cheek_visit1_Timm['Right_Cheek_Visit 1 - Timm L'],color='blue')

# %% [markdown]
# # Improvement after 7 Days of appllication of the product

# %%
plt.plot(Right_cheek_visit1_baseline['Right_Cheek_Visit 1 - Baseline L'],color='red')
plt.plot(Right_cheek_visit2['Right_Cheek_Visit 2 L'],color='green')

# %% [markdown]
# # Improvement after 14 Days of appllication of the product

# %%
plt.plot(Right_cheek_visit1_baseline['Right_Cheek_Visit 1 - Baseline L'],color='red')
plt.plot(Right_cheek_visit3['Right_Cheek_Visit 3 L'],color='black')

# %% [markdown]
# # CORNEOMETER ANALYSIS

# %%
# Read the Excel file into a pandas dataframe
df1 = pd.read_excel(pa,sheet_name="Instrument - Corneometer", header=[0])

# %%
#Dropping columns with more than 80% of missing values
df1.drop(['Unnamed: 0'],axis=1,inplace=True)

# %% [markdown]
# # Improvement after (15-20min) of application of the product

# %%
plt.plot(df1['Visit 1 - Baseline'],color='green')
plt.plot(df1['Visit 1 - Timm'],color='black')

# %% [markdown]
# # Improvement after 7 Days of appllication of the product

# %%
plt.plot(df1['Visit 1 - Baseline'],color='green')
plt.plot(df1['Visit 2'],color='red')

# %% [markdown]
# # Improvement after 14 Days of appllication of the product

# %%
plt.plot(df1['Visit 1 - Baseline'],color='green')
plt.plot(df1['Visit 3'],color='yellow')
